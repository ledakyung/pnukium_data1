# %% [markdown]
# # 6009 : [기초-입출력] 문자 1개 입력받아 그대로 출력하기(설명)(py)

# %%
a=input()
print(a)
# Out:
#   File "<ipython-input-1-b72d73619db5>", line 1
#     input a
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 6010 : [기초-입출력] 정수 1개 입력받아 int로 변환하여 출력하기(설명)(py)

# %%
a=int(input())
print(a)
# Out:
# 10
# 10

# %% [markdown]
# # 6011 : [기초-입출력] 실수 1개 입력받아 변환하여 출력하기(설명)(py)

# %%
a=float(input())
print(a)
# Out:
# 3.3
# 3.3

# %% [markdown]
# # 6012 : [기초-입출력] 정수 2개 입력받아 그대로 출력하기1(설명)(py)

# %%
a=int(input())
b=int(input())
print(a)
print(b)
# Out:
# 12
# 3
# 12
# 3

# %% [markdown]
# # 6013 : [기초-입출력] 문자 2개 입력받아 순서 바꿔 출력하기1(py)

# %%
a=input()
b=input()
print()
print()
# Out:
# sd
# pv

# %% [markdown]
# # 6014 : [기초-입출력] 실수 1개 입력받아 3번 출력하기(py)

# %%
a=int(input())
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# pv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae36f539a795> in <cell line: 4>()
#       2 print(a)
#       3 print(b)
# ----> 4 print(c)
#
# NameError: name 'c' is not defined

# %%
from IPython.core.async_helpers import inspect
a=int()

# %% [markdown]
# # 6015 : [기초-입출력] 정수 2개 입력받아 그대로 출력하기2(설명)(py)

# %%
a,b=input(),input()

print(a)
print(b)
# Out:
# 12
# 12
# 12
# 12

# %% [markdown]
# # 6016 : [기초-입출력] 문자 2개 입력받아 순서 바꿔 출력하기2(설명)(py)

# %%
a,b=input(),input()

print(b)
print(a)
# Out:
# 16
# 16
# 16
# 16

# %% [markdown]
# # 6017 : [기초-입출력] 문장 1개 입력받아 3번 출력하기(설명)(py)

# %%
a=input()
print(a)
print(a)
print(a)
# Out:
# 12
# 12
# 12
# 12

# %% [markdown]
# # 6018 : [기초-입출력] 시간 입력받아 그대로 출력하기(설명)(py)

# %%
a,b=sap(int,input())
print(a,b,seo~','))
# Out:
#   File "<ipython-input-2-7b0dd7a5de42>", line 2
#     print(a,b,seo~','))
#                       ^
# SyntaxError: unmatched ')'

# %% [markdown]
# # 6019 : [기초-입출력] 연월일 입력받아 순서 바꿔 출력하기(py)

# %%
y,s,d=sap(int,input()spilt(','))
print(a+b)
# Out:
#   File "<ipython-input-3-5b19696b41e9>", line 1
#     y,s,d=sap(int,input()spilt(','))
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # 6020 : [기초-입출력] 주민번호 입력받아 형태 바꿔 출력하기(py)

# %%
a,b=input(),spilt
print(a+b)
# Out:
# 000907~1121112
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-de7615e8d67b> in <cell line: 1>()
# ----> 1 a,b=input(),spilt
#       2 print(a+b)
#
# NameError: name 'spilt' is not defined

# %% [markdown]
# # 6021 : [기초-입출력] 단어 1개 입력받아 나누어 출력하기(설명)(py)

# %%
s=input()
print(s[o:2],s[2:4],s[4:5],sep='_')
# Out:
# 200304
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-78563dd79d57> in <cell line: 2>()
#       1 s=input()
# ----> 2 print(s[o:2],s[2:4],s[4:5],sep='_')
#
# NameError: name 'o' is not defined

# %% [markdown]
# # 6022 : [기초-입출력] 연월일 입력받아 나누어 출력하기(설명)(py)

# %%
s=input()
print(s(0:2),s[2:4],s[4:6],sep='_')
# Out:
#   File "<ipython-input-6-299706868652>", line 2
#     print(s(0:2),s[2:4],s[4:6],sep='_')
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 6023 : [기초-입출력] 시분초 입력받아 분만 출력하기(py)

# %%
h,m,s=input(),spilt(':')
print(m)
# Out:
# 6:00:00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-40bdc3b0e8b6> in <cell line: 1>()
# ----> 1 h,m,s=input(),spilt(':')
#       2 print(m)
#
# NameError: name 'spilt' is not defined

# %% [markdown]
# # 6024 : [기초-입출력] 단어 2개 입력받아 이어 붙이기(설명)(py)

# %%
a,b=input().spilt
print(a+b)
# Out:
# hello world
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e1f5e89f01bf> in <cell line: 1>()
# ----> 1 a,b=input().spilt
#       2 print(a+b)
#
# AttributeError: 'str' object has no attribute 'spilt'

# %% [markdown]
# # 6025 : [기초-값변환] 정수 2개 입력받아 합 계산하기(설명)(py)

# %%
a,b=map(int,input(),spilt())
print(a+b)
# Out:
# 10 20 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7a2eec4dd629> in <cell line: 1>()
# ----> 1 a,b=map(int,input(),spilt())
#       2 print(a+b)
#
# NameError: name 'spilt' is not defined

# %% [markdown]
# # 6026 : [기초-값변환] 실수 2개 입력받아 합 계산하기(설명)(py)a

# %%
a=float(input())
b=float(input())
cprint(a+b)
# Out:
# 1020
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7a2eec4dd629> in <cell line: 1>()
# ----> 1 a,b=map(int,input(),spilt())
#       2 print(a+b)
#
# NameError: name 'spilt' is not defined
